# %% [markdown]
# ##Exploratory Data Analysis - Terrorism

# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT DATASET**

# %%
df=pd.read_csv("/content/globalterrorismdb.csv",encoding='ISO-8859-1')
# Out:
# <ipython-input-4-18be2d791eec>:1: DtypeWarning: Columns (4,31,33,53,61,62,63,76,79,90,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/globalterrorismdb.csv",encoding='ISO-8859-1')

# %% [markdown]
# **VIEW FIRST FIVE DATA**

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# **VIEW LAST FIVE DATA**

# %%
df.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 71281  200011120004   2000      11    12        NaN         0        NaN
# 71282  200011120005   2000      11    12        NaN         0        NaN
# 71283  200011120006   2000      11    12        NaN         0        NaN
# 71284  200011120007   2000      11    12        NaN         0        NaN
# 71285  200011120008   2000      11    12        NaN         0        NaN
#
#        country country_txt  region  ...  \
# 71281       78      Greece       8  ...
# 71282       93   Indonesia       5  ...
# 71283      141       Nepal       6  ...
# 71284      141       Nepal       6  ...
# 71285      182     Somalia      11  ...
#
#                                                 addnotes  \
# 71281                                                NaN
# 71282  Hotinda Sihite was killed in the blast and Ime...
# 71283                                                NaN
# 71284                                                NaN
# 71285                                                NaN
#
#                                                   scite1 scite2  scite3  \
# 71281  "Greece-Bombs Bombs damage American, British b...    NaN     NaN
# 71282  "Detonator, timer found at Medan bomb blast si...    NaN     NaN
# 71283  "Bomb Blast Rock Kathmandu,Ó The Times of Indi...    NaN     NaN
# 71284  "Bomb Blast Rock Kathmandu,Ó The Times of Indi...    NaN     NaN
# 71285                                                NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 71281     CETIS      0.0       1.0      1.0     1.0
# 71282     CETIS     -9.0      -9.0      0.0    -9.0
# 71283     CETIS     -9.0      -9.0      0.0    -9.0
# 71284     CETIS     -9.0      -9.0      0.0    -9.0
# 71285       NaN      NaN       NaN      NaN     NaN
#
#                                         related
# 71281  200011120004, 200011120002, 200011120003
# 71282                                       NaN
# 71283                200011120006, 200011120007
# 71284                200011120007, 200011120006
# 71285                                       NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# **DESCRIPTIVE OF THE DATASET**

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  7.128600e+04  71286.000000  71286.000000  71286.000000  71286.000000
# mean   1.987603e+11   1987.537455      6.458070     15.355512      0.023132
# std    6.882547e+08      6.881972      3.387375      8.807646      0.150324
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.983012e+11   1983.000000      4.000000      8.000000      0.000000
# 50%    1.988092e+11   1988.000000      6.000000     15.000000      0.000000
# 75%    1.992102e+11   1992.000000      9.000000     23.000000      0.000000
# max    2.000111e+11   2000.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  71286.000000  71286.000000  67429.000000  67429.000000  71286.000000
# mean     146.942850      5.793382     18.660826    -10.810124      1.445417
# std      136.448114      3.203311     24.195317     65.393742      1.119820
# min        4.000000      1.000000    -53.154613   -176.176447      1.000000
# 25%       61.000000      3.000000      6.153669    -75.572173      1.000000
# 50%      110.000000      6.000000     16.482735     -2.311640      1.000000
# 75%      183.000000      8.000000     38.536667     35.211720      1.000000
# max     1003.000000     12.000000     74.633553    179.366667      5.000000
#
#        ...     ransomamt    ransomamtus    ransompaid  ransompaidus  \
# count  ...  7.280000e+02      48.000000  2.150000e+02     52.000000
# mean   ...  3.632422e+06   16233.500000  9.602683e+05   2197.730769
# std    ...  3.858626e+07   65452.728653  4.030259e+06   9231.590758
# min    ... -9.900000e+01     -99.000000 -9.900000e+01    -99.000000
# 25%    ...  0.000000e+00       0.000000  0.000000e+00      0.000000
# 50%    ...  2.500000e+04       0.000000  0.000000e+00      0.000000
# 75%    ...  5.925000e+05       0.000000  1.325000e+05      0.000000
# max    ...  1.000000e+09  400000.000000  4.100000e+07  48000.000000
#
#        hostkidoutcome    nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     2029.000000  1651.000000  71285.000000  71285.000000  71285.000000
# mean         3.507639    -2.694730     -3.754759     -3.712043      0.126240
# std          1.808528    51.187902      4.499236      4.555493      0.800361
# min          1.000000   -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000     1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000     1.000000      0.000000      0.000000      0.000000
# 75%          4.000000     3.000000      0.000000      0.000000      0.000000
# max          7.000000   750.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  71285.000000
# mean      -2.959557
# std        4.514898
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# **SHAPE OF THE DATASET**

# %%
df.shape
# Out:
# (71286, 135)

# %% [markdown]
# **INFORMATION OF THE DATASET**

# %%
df.info
# Out:
# <bound method DataFrame.info of             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 71281  200011120004   2000      11    12        NaN         0        NaN
# 71282  200011120005   2000      11    12        NaN         0        NaN
# 71283  200011120006   2000      11    12        NaN         0        NaN
# 71284  200011120007   2000      11    12        NaN         0        NaN
# 71285  200011120008   2000      11    12        NaN         0        NaN
#
#        country         country_txt  region  ...  \
# 0           58  Dominican Republic       2  ...
# 1          130              Mexico       1  ...
# 2          160         Philippines       5  ...
# 3           78              Greece       8  ...
# 4          101               Japan       4  ...
# ...        ...                 ...     ...  ...
# 71281       78              Greece       8  ...
# 71282       93           Indonesia       5  ...
# 71283      141               Nepal       6  ...
# 71284      141               Nepal       6  ...
# 71285      182             Somalia      11  ...
#
#                                                 addnotes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 71281                                                NaN
# 71282  Hotinda Sihite was killed in the blast and Ime...
# 71283                                                NaN
# 71284                                                NaN
# 71285                                                NaN
#
#                                                   scite1 scite2  scite3  \
# 0                                                    NaN    NaN     NaN
# 1                                                    NaN    NaN     NaN
# 2                                                    NaN    NaN     NaN
# 3                                                    NaN    NaN     NaN
# 4                                                    NaN    NaN     NaN
# ...                                                  ...    ...     ...
# 71281  "Greece-Bombs Bombs damage American, British b...    NaN     NaN
# 71282  "Detonator, timer found at Medan bomb blast si...    NaN     NaN
# 71283  "Bomb Blast Rock Kathmandu,Ó The Times of Indi...    NaN     NaN
# 71284  "Bomb Blast Rock Kathmandu,Ó The Times of Indi...    NaN     NaN
# 71285                                                NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0          PGIS      0.0       0.0      0.0     0.0
# 1          PGIS      0.0       1.0      1.0     1.0
# 2          PGIS     -9.0      -9.0      1.0     1.0
# 3          PGIS     -9.0      -9.0      1.0     1.0
# 4          PGIS     -9.0      -9.0      1.0     1.0
# ...         ...      ...       ...      ...     ...
# 71281     CETIS      0.0       1.0      1.0     1.0
# 71282     CETIS     -9.0      -9.0      0.0    -9.0
# 71283     CETIS     -9.0      -9.0      0.0    -9.0
# 71284     CETIS     -9.0      -9.0      0.0    -9.0
# 71285       NaN      NaN       NaN      NaN     NaN
#
#                                         related
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 71281  200011120004, 200011120002, 200011120003
# 71282                                       NaN
# 71283                200011120006, 200011120007
# 71284                200011120007, 200011120006
# 71285                                       NaN
#
# [71286 rows x 135 columns]>

# %% [markdown]
# **RENAMING THE COLUMNS**

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %% [markdown]
# **FINDING NULL VALUES**

# %%
df.isnull().sum()
# Out:
# eventid           0
# Year              0
# Month             0
# Day               0
# approxdate    71196
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       63555
# Length: 135, dtype: int64

# %% [markdown]
# **REPLACING NULL VALUES**

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# **MOST NUMBER OF ATTACK**

# %%
print("Country with the most attacks:",df['Country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1])
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Month with the most attacks:",df['Month'].value_counts().idxmax())
print("Group with the most attacks:",df['Group'].value_counts().index[1])
print("State with the most attacks:",df['state'].value_counts().idxmax())
print("Most Attack Types:",df['AttackType'].value_counts().idxmax())
# Out:
# Country with the most attacks: Colombia
# City with the most attacks: Lima
# Region with the most attacks: South America
# Year with the most attacks: 1992
# Month with the most attacks: 10
# Group with the most attacks: Shining Path (SL)
# State with the most attacks: Northern Ireland
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# **VISUALIZATION OF ATTACK OF YEARS**

# %%
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack_of_Years')
plt.show()

# %% [markdown]
# **VISUALIZATION OF ATTACK OF MONTHS**

# %%
x_month = df['Month'].unique()
y_count_month = df['Month'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Month')
plt.ylabel('Number of Attacks each month')
plt.title('Attack_of_Months')
plt.show()

# %% [markdown]
# **VISUALIZATION OF ATTACK OF DAYS**

# %%
x_day = df['Day'].unique()
y_count_day = df['Day'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Day')
plt.ylabel('Number of Attacks each day')
plt.title('Attack_of_Days')
plt.show()

# %% [markdown]
# **VISUALIZATION OF ATTACK OF ATTACKTYPE**

# %%
x_attacktype = df['AttackType'].unique()
y_count_attacktype = df['AttackType'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Type')
plt.ylabel('Number of Attacks')
plt.title('Attack_Type')
plt.show()

# %% [markdown]
# **VISUALIZATION OF TERRORIST ACTIVITIES BY REGION IN EACH YEAR**

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# **VISUALIZATION OF TERRORIST ACTIVITIES BY REGION IN EACH MONTH**

# %%
pd.crosstab(df.Month, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Month')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# **VISUALIZATION OF TERRORIST ACTIVITIES BY REGION IN EACH DAY**

# %%
pd.crosstab(df.Day, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Day')
plt.ylabel('Number of Attacks')
plt.show()
